# %%
install.packages("rstan")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘RcppParallel’, ‘checkmate’, ‘matrixStats’, ‘StanHeaders’, ‘inline’, ‘gridExtra’, ‘loo’, ‘RcppEigen’

# %%
set.seed(43)
library(rstan)
load("data_for_stan.RData")
print(params$stanfile)
options(mc.cores = parallel::detectCores())
print(data_list_england_wales)
# Out:
# Loading required package: StanHeaders
#
# Loading required package: ggplot2
#
# rstan (Version 2.19.3, GitRev: 2e1f913d3ca3)
#
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
# [1] "poison_time_dep.stan"
# $N
# [1] 18
#
# $E
#  [1] 12019.4 13051.7 12179.4 11737.0 11346.7 11124.7 10974.5 10981.2 10744.2
# [10] 10847.1 10682.2 10295.2  9646.6 10018.7 10345.3 10080.8 10007.4  9854.4
#
# $O
#  [1] 12254 14058 12990 11856 11612 10986 10944 10841 10816 10895 11019 10645
# [13] 11141 16387 18516 22351 21997 17953
#
# $sigma_a
# [1] 0
#
# $sigma_b
# [1] 0.2
#
# $alpha_mu
# [1] 0
#
# $alpha_sigma
# [1] 0.2
#
# $beta_a
# [1] -1
#
# $beta_b
# [1] 1
#
# $sigma_time_a
# [1] 0
#
# $sigma_time_b
# [1] 0.2

# %%
risk_england_wales_covid <- stan(params$stanfile, iter = params$iter, chains = 3,
    data = data_list_england_wales_covid, seed = 1, control = list(adapt_delta = params$adapt_delta, max_treedepth = params$max_treedepth))

save(risk_england_wales_covid,file="stan_output_england_covid.Rdata")

# %%
  
risk_norway_covid <- stan(params$stanfile, iter = params$iter, chains = 3,
    data = data_list_norway_covid, seed = 1, control = list(adapt_delta = params$adapt_delta, max_treedepth = params$max_treedepth))
  
save(risk_norway_covid,file="stan_output_norway_covid.Rdata")

# %%
risk_france_covid <- stan(params$stanfile, iter = params$iter, chains = 3,
    data = data_list_france_covid, seed = 1, control = list(adapt_delta = params$adapt_delta, max_treedepth = params$max_treedepth))
  

save(risk_france_covid,file="stan_output_france_covid.Rdata")

# %%
risk_belgium_covid <- stan(params$stanfile, iter = params$iter, chains = 3,
    data = data_list_belgium_covid, seed = 1, control = list(adapt_delta = params$adapt_delta, max_treedepth = params$max_treedepth))

save(risk_belgium_covid,file="stan_output_belgium_covid.Rdata")

# %%
save.image("stan_output_covid.Rdata")

# %%
print(risk_england_wales_covid)
# Out:
# Inference for Stan model: poison_time_dep.
# 3 chains, each with iter=5000; warmup=2500; thin=1;
# post-warmup draws per chain=2500, total post-warmup draws=7500.
#
#                          mean se_mean     sd       2.5%        25%        50%
# log_theta[1]             0.02    0.00   0.01       0.00       0.01       0.02
# log_theta[2]             0.01    0.00   0.02      -0.03       0.00       0.01
# log_theta[3]             0.01    0.00   0.02      -0.03      -0.01       0.01
# log_theta[4]            -0.01    0.00   0.02      -0.05      -0.02      -0.01
# log_theta[5]             0.00    0.00   0.02      -0.04      -0.01       0.00
# log_theta[6]            -0.01    0.00   0.02      -0.06      -0.02      -0.01
# log_theta[7]             0.00    0.00   0.02      -0.05      -0.01       0.00
# log_theta[8]            -0.01    0.00   0.02      -0.05      -0.02      -0.01
# log_theta[9]             0.00    0.00   0.02      -0.05      -0.01       0.00
# log_theta[10]           -0.01    0.00   0.02      -0.05      -0.02       0.00
# log_theta[11]            0.00    0.00   0.02      -0.05      -0.01       0.00
# log_theta[12]           -0.01    0.00   0.02      -0.06      -0.03      -0.01
# log_theta[13]            0.00    0.00   0.02      -0.04      -0.02       0.00
# log_theta[14]            0.03    0.00   0.03      -0.02       0.01       0.02
# log_theta[15]           -0.01    0.00   0.02      -0.06      -0.02      -0.01
# log_theta[16]            0.01    0.00   0.02      -0.03       0.00       0.01
# log_theta[17]            0.02    0.00   0.02      -0.02       0.00       0.01
# log_theta[18]           -0.01    0.00   0.02      -0.05      -0.02      -0.01
# log_theta_time[1]        0.01    0.00   0.02      -0.04      -0.01       0.01
# log_theta_time[2]        0.06    0.00   0.02       0.01       0.05       0.06
# log_theta_time[3]        0.06    0.00   0.02       0.01       0.04       0.06
# log_theta_time[4]        0.02    0.00   0.02      -0.02       0.01       0.02
# log_theta_time[5]        0.02    0.00   0.02      -0.02       0.01       0.02
# log_theta_time[6]        0.00    0.00   0.02      -0.05      -0.02       0.00
# log_theta_time[7]        0.00    0.00   0.02      -0.04      -0.01       0.00
# log_theta_time[8]        0.00    0.00   0.02      -0.05      -0.02      -0.01
# log_theta_time[9]        0.01    0.00   0.02      -0.03      -0.01       0.01
# log_theta_time[10]       0.01    0.00   0.02      -0.03       0.00       0.01
# log_theta_time[11]       0.03    0.00   0.02      -0.01       0.02       0.03
# log_theta_time[12]       0.04    0.00   0.02       0.00       0.02       0.04
# log_theta_time[13]       0.09    0.00   0.02       0.05       0.08       0.09
# log_theta_time[14]       0.16    0.00   0.03       0.10       0.15       0.17
# log_theta_time[15]       0.13    0.00   0.02       0.08       0.11       0.12
# log_theta_time[16]       0.16    0.00   0.02       0.11       0.15       0.16
# log_theta_time[17]       0.17    0.00   0.03       0.11       0.16       0.17
# log_theta_time[18]       0.13    0.00   0.02       0.08       0.11       0.13
# sigma                    0.02    0.00   0.01       0.01       0.02       0.02
# alpha                    0.02    0.00   0.01       0.00       0.01       0.02
# beta                     0.75    0.00   0.18       0.34       0.66       0.79
# sigma_time               0.04    0.00   0.01       0.02       0.04       0.04
# sim[1]               12211.07    1.85 151.16   11917.48   12108.00   12211.00
# sim[2]               14034.36    1.88 165.78   13713.47   13923.00   14036.00
# sim[3]               12975.61    1.86 162.13   12668.47   12864.00   12974.00
# sim[4]               11870.37    1.78 151.81   11571.00   11768.00   11872.00
# sim[5]               11607.13    1.72 150.39   11317.48   11504.00   11605.00
# sim[6]               10998.70    1.70 148.56   10714.00   10896.00   10997.00
# sim[7]               10942.85    1.67 146.81   10653.00   10843.00   10943.00
# sim[8]               10851.12    1.58 144.81   10574.00   10753.00   10849.00
# sim[9]               10816.18    1.67 145.69   10531.00   10717.75   10817.00
# sim[10]              10903.63    1.65 144.52   10621.00   10805.00   10903.00
# sim[11]              11015.36    1.70 149.62   10722.48   10914.00   11013.00
# sim[12]              10663.71    1.67 144.22   10385.00   10566.00   10663.00
# sim[13]              11144.30    1.74 149.40   10856.00   11042.75   11144.00
# sim[14]              16338.30    2.09 181.32   15985.47   16216.00   16339.00
# sim[15]              18546.18    2.13 186.62   18182.47   18421.00   18544.00
# sim[16]              22338.04    2.35 207.66   21930.00   22200.00   22337.00
# sim[17]              21968.05    2.31 208.85   21563.00   21827.75   21966.00
# sim[18]              17966.60    2.17 189.83   17597.47   17839.00   17965.00
# lp__               2117557.82    0.20   6.90 2117542.95 2117553.45 2117558.24
#                           75%      97.5% n_eff Rhat
# log_theta[1]             0.02       0.03  6844    1
# log_theta[2]             0.03       0.07  3206    1
# log_theta[3]             0.02       0.06  3577    1
# log_theta[4]             0.00       0.03  5564    1
# log_theta[5]             0.02       0.04  4824    1
# log_theta[6]             0.00       0.03  3241    1
# log_theta[7]             0.01       0.04  4073    1
# log_theta[8]             0.01       0.03  3051    1
# log_theta[9]             0.01       0.04  3881    1
# log_theta[10]            0.01       0.03  3619    1
# log_theta[11]            0.01       0.04  4469    1
# log_theta[12]            0.00       0.03  2937    1
# log_theta[13]            0.01       0.04  5552    1
# log_theta[14]            0.04       0.09  1565    1
# log_theta[15]            0.00       0.03  2949    1
# log_theta[16]            0.02       0.06  2316    1
# log_theta[17]            0.03       0.07  1623    1
# log_theta[18]            0.01       0.04  3753    1
# log_theta_time[1]        0.02       0.06  7141    1
# log_theta_time[2]        0.08       0.10  3208    1
# log_theta_time[3]        0.07       0.10  3774    1
# log_theta_time[4]        0.03       0.06  5562    1
# log_theta_time[5]        0.03       0.06  4976    1
# log_theta_time[6]        0.01       0.05  3650    1
# log_theta_time[7]        0.01       0.05  4092    1
# log_theta_time[8]        0.01       0.04  2943    1
# log_theta_time[9]        0.02       0.05  3967    1
# log_theta_time[10]       0.02       0.06  3534    1
# log_theta_time[11]       0.04       0.08  4654    1
# log_theta_time[12]       0.05       0.09  3155    1
# log_theta_time[13]       0.11       0.13  5453    1
# log_theta_time[14]       0.18       0.21  1711    1
# log_theta_time[15]       0.14       0.17  3084    1
# log_theta_time[16]       0.18       0.20  2453    1
# log_theta_time[17]       0.19       0.21  1761    1
# log_theta_time[18]       0.14       0.18  3760    1
# sigma                    0.03       0.05   897    1
# alpha                    0.03       0.05  3636    1
# beta                     0.88       0.98  1506    1
# sigma_time               0.05       0.07  2220    1
# sim[1]               12310.00   12513.00  6685    1
# sim[2]               14146.00   14361.00  7758    1
# sim[3]               13084.00   13302.52  7616    1
# sim[4]               11973.25   12170.00  7254    1
# sim[5]               11707.00   11903.52  7628    1
# sim[6]               11098.25   11291.52  7607    1
# sim[7]               11043.00   11229.00  7691    1
# sim[8]               10949.00   11136.52  8347    1
# sim[9]               10916.00   11097.00  7566    1
# sim[10]              11003.00   11187.52  7628    1
# sim[11]              11118.00   11308.52  7737    1
# sim[12]              10759.00   10952.00  7438    1
# sim[13]              11246.00   11439.05  7381    1
# sim[14]              16458.00   16695.53  7535    1
# sim[15]              18670.00   18914.00  7673    1
# sim[16]              22479.00   22739.00  7813    1
# sim[17]              22108.00   22380.53  8172    1
# sim[18]              18093.25   18341.00  7687    1
# lp__               2117562.67 2117569.89  1179    1
#
# Samples were drawn using NUTS(diag_e) at Wed Jun 10 18:58:39 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
